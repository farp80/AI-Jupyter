# %% [markdown]
# <a href="https://colab.research.google.com/github/farp80/AI-Jupyter/blob/develop/jupyter-initial-wk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
print("+"*20)
# Out:
# hello
# ++++++++++++++++++++
